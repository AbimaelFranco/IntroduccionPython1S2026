# %% [markdown]
# <a href="https://colab.research.google.com/github/AbimaelFranco/IntroduccionPython1S2026/blob/main/IPP_Sesion6_1S2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la Programación en Python - Sesión 5
#
# ## Contenido de la Sesión
#
# * Scripts y Módulos
# * Librerias
# * Uso de Pip
# * Librerias estándar (`math, os, random, datetime`)
# * Librerias externas
# * Potencial de las librerias

# %% [markdown]
# ## Scripts y Módulos
#
# Un script es simplemente un archivo de Python (.py) que contiene instrucciones para ejecutar una tarea.
#
# Ejemplo: un script que imprime "Hola Mundo".
#
# Un módulo es también un archivo .py, pero su objetivo no es ejecutarse directamente, sino almacenar funciones, clases o variables que otros scripts pueden reutilizar.
#
# Diferencia clave:
#
# Script → se ejecuta.
#
# Módulo → se importa.
#
# Para importar un módulo a un script se emplea la palabra reservada `import`

# %% [markdown]
# ## Librerías
#
# Una librería es un conjunto de módulos organizados que ofrecen soluciones ya listas.
#
# Permiten reutilizar código confiable en lugar de programar todo desde cero.
#
# Ejemplo conceptual: una librería es como una caja de herramientas, donde cada módulo es una herramienta lista para usar.

# %% [markdown]
# ## Uso de Pip
#
# pip es el gestor de paquetes oficial de Python.
#
# Permite instalar, actualizar o eliminar librerías externas desde internet.
#
# Ejemplo conceptual: imagina que tu computadora es un taller, y con pip puedes ir a la tienda y traer nuevas herramientas.
#
# Comandos básicos:
#
# Para instalar una libreria: `pip install nombre_libreria`
#
# Para desinstalar una libreria: `pip uninstall nombre_libreria`
#
# Para listar las librerias instaladas: `pip list`

# %% [markdown]
# ## Librerías estándar de Python
#
# Python ya incluye una colección de librerías listas para usar, conocida como la librería estándar. Algunos ejemplos:
#
# * **math:** Funciones matemáticas (raíces, trigonometría, constantes).
#
# * **os:** Interactuar con el sistema operativo (rutas, archivos, carpetas).
#
# * **random:** Generar valores aleatorios (muy útil en juegos o simulaciones).
#
# * **datetime:** Trabajar con fechas y horas (calendarios, intervalos de tiempo).

# %%
import math
import os
import random
import datetime

# Uso de math → calcular raíz cuadrada
numero = 25
raiz = math.sqrt(numero)
print(f"La raíz cuadrada de {numero} es {raiz}")

# Uso de os → mostrar el directorio actual
directorio_actual = os.getcwd()
print(f"Directorio actual: {directorio_actual}")

# Uso de random → elegir un número aleatorio entre 1 y 10
numero_aleatorio = random.randint(1, 10)
print(f"Número aleatorio generado: {numero_aleatorio}")

# Uso de datetime → obtener la fecha y hora actual
fecha_actual = datetime.datetime.now()
print(f"Fecha y hora actual: {fecha_actual}")
# Out:
# La raíz cuadrada de 25 es 5.0
# Directorio actual: /content
# Número aleatorio generado: 2
# Fecha y hora actual: 2025-09-11 05:47:22.774550

# %%
import random

def lanzar_dados():
    """Lanza dos dados y devuelve sus valores como tupla."""
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)
    return dado1, dado2

def jugar():
    """Ejecuta el ciclo principal del juego de dados."""
    puntuacion = 0
    print("🎲 Bienvenido al juego de dados 🎲")

    while True:
        opcion = input("\n¿Quieres lanzar los dados? (jugar/salir): ").lower()

        if opcion == "salir":
            print(f"\nGracias por jugar. Tu puntuación final es: {puntuacion}")
            break
        elif opcion == "jugar":
            dado1, dado2 = lanzar_dados()
            suma = dado1 + dado2
            puntuacion += suma

            print(f"Lanzaste: {dado1} y {dado2} → total: {suma}")
            print(f"Puntuación acumulada: {puntuacion}")
        else:
            print("⚠️ Opción no válida. Escribe 'jugar' o 'salir'.")

jugar()
# Out:
# 🎲 Bienvenido al juego de dados 🎲
#
# ¿Quieres lanzar los dados? (jugar/salir): jugar
# Lanzaste: 3 y 6 → total: 9
# Puntuación acumulada: 9
#
# ¿Quieres lanzar los dados? (jugar/salir): jugar
# Lanzaste: 3 y 4 → total: 7
# Puntuación acumulada: 16
#
# ¿Quieres lanzar los dados? (jugar/salir): salir
#
# Gracias por jugar. Tu puntuación final es: 16

# %% [markdown]
# ## Librerías Externas
#
# Además de las librerías estándar, la comunidad ha desarrollado miles de librerías que amplían el potencial de Python.
#
# numpy → Cálculo numérico avanzado.
#
# pandas → Análisis y manipulación de datos.
#
# matplotlib → Crear gráficos y visualizaciones.
#
# requests → Conectar con internet y consumir APIs.

# %%
#asegurarse de tener instalado las librerias
#colab las tiene instaladas por defecto

#numpy: pip install numpy
#matlplotlib: pip install matplotlib

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Crear una malla de coordenadas
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Definir dos funciones
Z1 = np.sin(np.sqrt(X**2 + Y**2))
Z2 = np.cos(X) * np.sin(Y)

# Crear figura y ejes
fig, axs = plt.subplots(2, 2, figsize=(10, 8), subplot_kw={"projection": None})

# --- Gráfico superior izquierdo (3D de Z1)
ax1 = fig.add_subplot(2, 2, 1, projection="3d")
surf1 = ax1.plot_surface(X, Y, Z1, cmap="viridis")
ax1.set_title("Superficie 3D - Función Z1")
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=8)

# --- Gráfico superior derecho (3D de Z2)
ax2 = fig.add_subplot(2, 2, 2, projection="3d")
surf2 = ax2.plot_surface(X, Y, Z2, cmap="plasma")
ax2.set_title("Superficie 3D - Función Z2")
fig.colorbar(surf2, ax=ax2, shrink=0.5, aspect=8)

# --- Gráfico inferior izquierdo (curvas de nivel de Z1)
ax3 = fig.add_subplot(2, 2, 3)
contour1 = ax3.contourf(X, Y, Z1, cmap="viridis")
ax3.set_title("Curvas de nivel - Z1")
fig.colorbar(contour1, ax=ax3)

# --- Gráfico inferior derecho (curvas de nivel de Z2)
ax4 = fig.add_subplot(2, 2, 4)
contour2 = ax4.contourf(X, Y, Z2, cmap="plasma")
ax4.set_title("Curvas de nivel - Z2")
fig.colorbar(contour2, ax=ax4)

# Ajustar espaciado
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Potencial de las librerías en Python
#
# El verdadero poder de **Python** está en sus librerías, que permiten transformar un lenguaje simple en una plataforma poderosa para diversas áreas como ciencia de datos, inteligencia artificial, desarrollo web, automatización y mucho más.
#
# ---
#
# ### 📊 Ciencia de Datos
# - **pandas** → Manipulación y análisis de datos en estructuras tipo DataFrame.
# - **NumPy** → Cálculo numérico eficiente y manejo de arreglos multidimensionales.
# - **Matplotlib** → Visualización de datos mediante gráficos 2D y 3D.
#
# ---
#
# ### 🤖 Inteligencia Artificial & Machine Learning
# - **Scikit-learn** → Algoritmos de Machine Learning clásicos.
# - **TensorFlow** → Redes neuronales y deep learning a gran escala.
# - **PyTorch** → Framework flexible para deep learning e investigación en IA.
#
# ---
#
# ### 🌐 Desarrollo Web
# - **Django** → Framework completo para desarrollo web rápido y seguro.
# - **Flask** → Framework minimalista para crear APIs y aplicaciones web ligeras.
# - **FastAPI** → Creación de APIs rápidas y modernas con validación automática.
#
# ---
#
# ### ⚙️ Automatización & Web Scraping
# - **Selenium** → Automatización de navegadores para pruebas y scraping.
# - **BeautifulSoup** → Extracción de datos de páginas HTML y XML.
# - **Requests** → Cliente HTTP simple y poderoso.
#
# ---
#
# ### 🧪 Ciencia & Cálculo
# - **SymPy** → Matemáticas simbólicas y álgebra computacional.
# - **SciPy** → Cálculo científico avanzado y optimización.
# - **NetworkX** → Análisis de grafos y redes complejas.
#
# ---
#
# ### 🎮 Juegos & Gráficos
# - **Pygame** → Desarrollo de videojuegos en 2D.
# - **Arcade** → Librería moderna y sencilla para crear videojuegos.
# - **ModernGL** → Acceso a OpenGL moderno para gráficos 3D.
#
# ---
# ### 🔐 Ciberseguridad
# - **Scapy** → Creación, análisis y manipulación de paquetes de red.
# - **Impacket** → Implementación de protocolos de red para pentesting.
# - **Paramiko** → Automatización y conexiones seguras mediante SSH.
# - **Cryptography** → Implementación de cifrado, firmas digitales y protocolos seguros.
#
# ---
#
# ### 👁️ Visión Artificial
# - **OpenCV** → Procesamiento de imágenes, detección de objetos, visión por computadora.
# - **MediaPipe** → Detección de manos, rostros, poses y seguimiento en tiempo real.
# - **Scikit-Image** → Procesamiento avanzado de imágenes científicas.
# - **Pillow** → Manipulación básica de imágenes (corte, filtros, conversión de formatos).
